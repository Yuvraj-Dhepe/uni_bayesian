# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pdf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1.1

# %% [markdown]
# <img src = "./1.1.jpg">

# %%
def UniformMidpointRule(last_M:int,interval:int) -> tuple:
    """
    Get the f_m_bar approximation for every M number of points
    @param: last_M: Total Quadrature Point Count till which approximation has to be generated at regular interval starting from 10 Points
    @param: interval: M has to be chosen per this param interval
    """
    ## List of number of Quadrature points to generate function approximation on
    M = np.arange(2,last_M+interval,interval)
    f_m_unif = []

    ## Generating approximate function for m number of Quadrature points
    for m in M:
        sum = 0
        ## Calculating the f_m for every M value
        for i in range(1,m+1):
            b_i = float(1/m)
            c_i = float((1/(2*m)) + ((i-1)/(m)))
            sum += float(b_i*np.sqrt(1-(c_i)**2))
        ## f_M
        f_m_unif.append(sum)
    f_m_unif = np.array(f_m_unif)

    #f_m3_uni_midpoint = f_m_unif[2] # To compare with the 2nd question

    return M,f_m_unif

def UniformMidpointPlot(last_M:int,interval:int, err_plot: bool)-> None:
    """
    Generate the plot for Uniform Interval midpoint rule quadrature points
    @param: last_M: Total Quadrature Point Count till which approximation has to be generated at regular interval starting from 10 Points
    @param: interval: M has to be chosen per this param interval
    @param: err_plot: To Generate error plot or not for function approximation produced at m quadrature points
    """

    # Obtaining the Quadrature points and Respective function approximation via use of uniform midpoint rule
    M,f_MC = UniformMidpointRule(last_M,interval)
    error = f_MC-(np.pi/4)

    # Subplots
    fig,axs= plt.subplots(2,1,figsize= (20,12))

    # Sub Plot 1
    # Plotting the line
    axs[0].plot(M,f_MC, label='Line')
    # Plotting the points
    axs[0].scatter(M,f_MC, color='red')
    # Plotting the pi/4 line
    axs[0].axhline(y=(np.pi)/4, color='purple', linestyle='-', linewidth=1, label = 'pi/4')
    # Adding labels and title
    axs[0].set_xlabel("Number of Quadrature Points")
    axs[0].set_ylabel("Error")
    axs[0].set_title('Function approximation with Uniform Interval Midpoint rule')
    # Adding legend
    axs[0].legend()

    if err_plot:
        axs[1].plot(M,error, label = 'approximation_error')
        axs[1].scatter(M,error)
        axs[1].set_xlabel("Number of Quadrature Points M")
        axs[1].set_ylabel("Function Error for M points")
        axs[1].set_title("Uniform Interval Midpoint Rule Simulation Errors")
        axs[1].legend()
    # Display the plot
    plt.show()

UniformMidpointPlot(last_M = 30,interval = 1,err_plot = 1)

# %% [markdown]
# #### Observations for Problem 1.1

# %% [markdown]
# - The error goes down as we increase the quadrature points

# %% [markdown]
# ## Problem 1.2

# %% [markdown]
# <img src = "./1.2.jpg">

# %%
b_i =  np.array([4/9,5/18,5/18])
c_i = np.array([0,np.sqrt(3/5),-1 * np.sqrt(3/5)])

f_m_gauss = []
for m in range(1,4):
    sum = 0
    for j in range(0,m):
        sum += b_i[j]*np.sqrt(1-(c_i[j]**2))
    f_m_gauss.append(sum)

_,f_m_unif = UniformMidpointRule(last_M=30,interval=1)

f_m_gauss = np.array(f_m_gauss)

(f_m_unif[:3] -np.pi/4),(f_m_gauss - np.pi/4)
# Out:
# (array([0.02944367, 0.016205  , 0.01058414]),
#  array([-0.34095372, -0.16527163,  0.01041047]))

# %% [markdown]
# #### Observations for Problem 1.2

# %% [markdown]
# - Observing the gauss approximation, we can see that function approximation almost became same for 3 quadrature points.

# %% [markdown]
# ## Problem 1.3

# %% [markdown]
# <img src = './1.3.jpg'>

# %%
def AreaApprox(M: int)-> float:
    '''
    Generate Circle area approximation for M quadrature points
    @param: M: Count of Quadrature points
    '''
    ## Drawing a pair of random numbers
    x = np.random.uniform(size = M)
    y = np.random.uniform(size = M)

    hits = 0
    ## Seeing how many points lie in the circle
    for iterate in range(M):

        if (x[iterate]**2 + y[iterate]**2 <=1):
            hits += 1

    ## Returning the area approximation for M points
    return hits/M

def MonteCarloRule(last_M:int,interval:int)-> tuple:
    """
    Get the f_m_bar approximation for given M points via MonteCarlo Rule
    @param: last_M: Total Quadrature Point Count till which approximation has to be generated at regular interval starting from 10 Points
    @param: interval: M has to be chosen per this param interval
    """
    ## List of number of Quadrature points to generate function approximation on
    M = list(range(10,last_M+interval,interval))

    ## Getting area approximations for different values of M
    f_MC = np.array([AreaApprox(m) for m in M])
    
    return M,f_MC

def MonteCarloPlot(last_m: int,interval: int,err_plot: bool)-> None:
    """
    Get the f_m_bar approximation and error plot for given M points via MonteCarlo Rule
    @param: last_M: Total Quadrature Point Count till which approximation has to be generated at regular interval starting from 10 Points
    @param: interval: M has to be chosen per this param interval
    @param: err_plot: Whether to generate error plot or not
    """
    # Obtaining the Quadrature points and Respective function approximation via use of uniform midpoint rule
    M,f_MC = MonteCarloRule(last_m,interval)

    ## Generating Subplots for Approximation and Errors
    fig,axs = plt.subplots(2,1,figsize= (20,12))
    ## Generating the plot
    axs[0].plot(M,f_MC, label = 'f_MC')
    axs[0].scatter(M,f_MC)
    
    # Plot lines at pi/4
    axs[0].axhline(y=(np.pi)/4, color='purple', linestyle='-', linewidth=1, label = 'pi/4')

    ## Adding visual information
    axs[0].set_xlabel("Number of Quadrature Points M")
    axs[0].set_ylabel("Function Approximation for M points")
    axs[0].set_title("Monte Carlo Method Simulation")
    axs[0].legend()
    
    if err_plot:
        err = f_MC - np.pi/4
        axs[1].plot(M,err, label = 'approximation_error')
        axs[1].scatter(M,err)
        axs[1].set_xlabel("Number of Quadrature Points M")
        axs[1].set_ylabel("Function Error for M points")
        axs[1].set_title("Monte Carlo Method Simulation Errors")
        axs[1].legend()


    plt.show()

interval = 10
f_MC = MonteCarloPlot(last_m = 500,interval = interval,err_plot = 1)

# %% [markdown]
# #### Observations for Problem 1.3

# %% [markdown]
# - The error goes down as we increase the quadrature points

# %% [markdown]
# ## Problem 1.4

# %% [markdown]
# <img src = './1.4.jpg'>

# %%
interval = 1000
MonteCarloPlot(last_m = int(1e5),interval = interval,err_plot = 1)

# %%
def zero_error_points(f_approximations:np.array,limit: float,interval:int):
    for index,approximation in enumerate(f_approximations):
        val = (approximation - (np.pi/4))
        if -1*limit<val<limit:
            print(f"Error is almost 0 for approximation value: {approximation}, and {index*interval} quadrature points with error: {val:.9f}")

# %%
interval = 100
_, f_MC = MonteCarloRule(last_M = int(1e5),interval = interval)
_, f_uniform = UniformMidpointRule(last_M = int(1e5),interval = interval)

# %%
print("Monte Carlo Rule Simulation")
zero_error_points(f_MC,limit = 1e-5,interval = interval)
print("======================================")
print("Uniform Midpoint Rule Simulation")
zero_error_points(f_uniform,limit = 1e-6,interval= interval)
# Out:
# Monte Carlo Rule Simulation
# Error is almost 0 for approximation value: 0.7854002488593944, and 24100 quadrature points with error: 0.000002085
# Error is almost 0 for approximation value: 0.7854021279029859, and 87400 quadrature points with error: 0.000003965
# Error is almost 0 for approximation value: 0.7853886678851736, and 93000 quadrature points with error: -0.000009496
# ======================================
# Uniform Midpoint Rule Simulation
# Error is almost 0 for approximation value: 0.7853991246538456, and 2000 quadrature points with error: 0.000000961
# Error is almost 0 for approximation value: 0.7853990568818704, and 2100 quadrature points with error: 0.000000893
# Error is almost 0 for approximation value: 0.7853989967153576, and 2200 quadrature points with error: 0.000000833
# Error is almost 0 for approximation value: 0.7853989430108329, and 2300 quadrature points with error: 0.000000780
# Error is almost 0 for approximation value: 0.7853988948367499, and 2400 quadrature points with error: 0.000000731
# Error is almost 0 for approximation value: 0.7853988514273735, and 2500 quadrature points with error: 0.000000688
# Error is almost 0 for approximation value: 0.7853988121480894, and 2600 quadrature points with error: 0.000000649
# Error is almost 0 for approximation value: 0.7853987764689631, and 2700 quadrature points with error: 0.000000613
# Error is almost 0 for approximation value: 0.7853987439443968, and 2800 quadrature points with error: 0.000000581
# Error is almost 0 for approximation value: 0.785398714197271, and 2900 quadrature points with error: 0.000000551
# Error is almost 0 for approximation value: 0.7853986869065177, and 3000 quadrature points with error: 0.000000524
# Error is almost 0 for approximation value: 0.7853986617972575, and 3100 quadrature points with error: 0.000000498
# Error is almost 0 for approximation value: 0.7853986386329331, and 3200 quadrature points with error: 0.000000475
# Error is almost 0 for approximation value: 0.7853986172089801, and 3300 quadrature points with error: 0.000000454
# Error is almost 0 for approximation value: 0.7853985973476809, and 3400 quadrature points with error: 0.000000434
# Error is almost 0 for approximation value: 0.7853985788940026, and 3500 quadrature points with error: 0.000000415
# Error is almost 0 for approximation value: 0.7853985617121233, and 3600 quadrature points with error: 0.000000398
# Error is almost 0 for approximation value: 0.7853985456826368, and 3700 quadrature points with error: 0.000000382
# Error is almost 0 for approximation value: 0.7853985307001566, and 3800 quadrature points with error: 0.000000367
# Error is almost 0 for approximation value: 0.7853985166713878, and 3900 quadrature points with error: 0.000000353
# Error is almost 0 for approximation value: 0.7853985035134469, and 4000 quadrature points with error: 0.000000340
# Error is almost 0 for approximation value: 0.7853984911524892, and 4100 quadrature points with error: 0.000000328
# Error is almost 0 for approximation value: 0.7853984795225349, and 4200 quadrature points with error: 0.000000316
# Error is almost 0 for approximation value: 0.7853984685644619, and 4300 quadrature points with error: 0.000000305
# Error is almost 0 for approximation value: 0.7853984582251593, and 4400 quadrature points with error: 0.000000295
# Error is almost 0 for approximation value: 0.7853984484567805, and 4500 quadrature points with error: 0.000000285
# Error is almost 0 for approximation value: 0.785398439216157, and 4600 quadrature points with error: 0.000000276
# Error is almost 0 for approximation value: 0.7853984304642097, and 4700 quadrature points with error: 0.000000267
# Error is almost 0 for approximation value: 0.7853984221655118, and 4800 quadrature points with error: 0.000000259
# Error is almost 0 for approximation value: 0.7853984142878646, and 4900 quadrature points with error: 0.000000251
# Error is almost 0 for approximation value: 0.785398406801959, and 5000 quadrature points with error: 0.000000243
# Error is almost 0 for approximation value: 0.785398399681058, and 5100 quadrature points with error: 0.000000236
# Error is almost 0 for approximation value: 0.7853983929007109, and 5200 quadrature points with error: 0.000000230
# Error is almost 0 for approximation value: 0.7853983864385498, and 5300 quadrature points with error: 0.000000223
# Error is almost 0 for approximation value: 0.7853983802740618, and 5400 quadrature points with error: 0.000000217
# Error is almost 0 for approximation value: 0.785398374388388, and 5500 quadrature points with error: 0.000000211
# Error is almost 0 for approximation value: 0.785398368764194, and 5600 quadrature points with error: 0.000000205
# Error is almost 0 for approximation value: 0.7853983633855041, and 5700 quadrature points with error: 0.000000200
# Error is almost 0 for approximation value: 0.7853983582375641, and 5800 quadrature points with error: 0.000000195
# Error is almost 0 for approximation value: 0.7853983533067527, and 5900 quadrature points with error: 0.000000190
# Error is almost 0 for approximation value: 0.7853983485804648, and 6000 quadrature points with error: 0.000000185
# Error is almost 0 for approximation value: 0.7853983440470086, and 6100 quadrature points with error: 0.000000181
# Error is almost 0 for approximation value: 0.7853983396955532, and 6200 quadrature points with error: 0.000000176
# Error is almost 0 for approximation value: 0.7853983355160354, and 6300 quadrature points with error: 0.000000172
# Error is almost 0 for approximation value: 0.785398331499084, and 6400 quadrature points with error: 0.000000168
# Error is almost 0 for approximation value: 0.7853983276359833, and 6500 quadrature points with error: 0.000000164
# Error is almost 0 for approximation value: 0.7853983239186093, and 6600 quadrature points with error: 0.000000161
# Error is almost 0 for approximation value: 0.7853983203393857, and 6700 quadrature points with error: 0.000000157
# Error is almost 0 for approximation value: 0.7853983168912234, and 6800 quadrature points with error: 0.000000153
# Error is almost 0 for approximation value: 0.785398313567505, and 6900 quadrature points with error: 0.000000150
# Error is almost 0 for approximation value: 0.7853983103620278, and 7000 quadrature points with error: 0.000000147
# Error is almost 0 for approximation value: 0.7853983072689859, and 7100 quadrature points with error: 0.000000144
# Error is almost 0 for approximation value: 0.7853983042829412, and 7200 quadrature points with error: 0.000000141
# Error is almost 0 for approximation value: 0.7853983013987758, and 7300 quadrature points with error: 0.000000138
# Error is almost 0 for approximation value: 0.7853982986116915, and 7400 quadrature points with error: 0.000000135
# Error is almost 0 for approximation value: 0.7853982959171739, and 7500 quadrature points with error: 0.000000133
# Error is almost 0 for approximation value: 0.7853982933109712, and 7600 quadrature points with error: 0.000000130
# Error is almost 0 for approximation value: 0.7853982907890901, and 7700 quadrature points with error: 0.000000127
# Error is almost 0 for approximation value: 0.7853982883477656, and 7800 quadrature points with error: 0.000000125
# Error is almost 0 for approximation value: 0.785398285983418, and 7900 quadrature points with error: 0.000000123
# Error is almost 0 for approximation value: 0.7853982836927116, and 8000 quadrature points with error: 0.000000120
# Error is almost 0 for approximation value: 0.7853982814724699, and 8100 quadrature points with error: 0.000000118
# Error is almost 0 for approximation value: 0.7853982793196975, and 8200 quadrature points with error: 0.000000116
# Error is almost 0 for approximation value: 0.7853982772315545, and 8300 quadrature points with error: 0.000000114
# Error is almost 0 for approximation value: 0.7853982752053555, and 8400 quadrature points with error: 0.000000112
# Error is almost 0 for approximation value: 0.7853982732385599, and 8500 quadrature points with error: 0.000000110
# Error is almost 0 for approximation value: 0.785398271328758, and 8600 quadrature points with error: 0.000000108
# Error is almost 0 for approximation value: 0.7853982694736662, and 8700 quadrature points with error: 0.000000106
# Error is almost 0 for approximation value: 0.7853982676711146, and 8800 quadrature points with error: 0.000000104
# Error is almost 0 for approximation value: 0.78539826591904, and 8900 quadrature points with error: 0.000000103
# Error is almost 0 for approximation value: 0.785398264215487, and 9000 quadrature points with error: 0.000000101
# Error is almost 0 for approximation value: 0.7853982625585942, and 9100 quadrature points with error: 0.000000099
# Error is almost 0 for approximation value: 0.7853982609465986, and 9200 quadrature points with error: 0.000000098
# Error is almost 0 for approximation value: 0.7853982593778099, and 9300 quadrature points with error: 0.000000096
# Error is almost 0 for approximation value: 0.785398257850613, and 9400 quadrature points with error: 0.000000094
# Error is almost 0 for approximation value: 0.7853982563635029, and 9500 quadrature points with error: 0.000000093
# Error is almost 0 for approximation value: 0.7853982549150056, and 9600 quadrature points with error: 0.000000092
# Error is almost 0 for approximation value: 0.7853982535037367, and 9700 quadrature points with error: 0.000000090
# Error is almost 0 for approximation value: 0.7853982521283697, and 9800 quadrature points with error: 0.000000089
# Error is almost 0 for approximation value: 0.7853982507876369, and 9900 quadrature points with error: 0.000000087
# Error is almost 0 for approximation value: 0.7853982494803322, and 10000 quadrature points with error: 0.000000086
# Error is almost 0 for approximation value: 0.7853982482053006, and 10100 quadrature points with error: 0.000000085
# Error is almost 0 for approximation value: 0.785398246961439, and 10200 quadrature points with error: 0.000000084
# Error is almost 0 for approximation value: 0.7853982457476839, and 10300 quadrature points with error: 0.000000082
# Error is almost 0 for approximation value: 0.7853982445630319, and 10400 quadrature points with error: 0.000000081
# Error is almost 0 for approximation value: 0.7853982434065148, and 10500 quadrature points with error: 0.000000080
# Error is almost 0 for approximation value: 0.785398242277206, and 10600 quadrature points with error: 0.000000079
# Error is almost 0 for approximation value: 0.785398241174213, and 10700 quadrature points with error: 0.000000078
# Error is almost 0 for approximation value: 0.7853982400966909, and 10800 quadrature points with error: 0.000000077
# Error is almost 0 for approximation value: 0.7853982390438157, and 10900 quadrature points with error: 0.000000076
# Error is almost 0 for approximation value: 0.7853982380148162, and 11000 quadrature points with error: 0.000000075
# Error is almost 0 for approximation value: 0.7853982370089275, and 11100 quadrature points with error: 0.000000074
# Error is almost 0 for approximation value: 0.7853982360254415, and 11200 quadrature points with error: 0.000000073
# Error is almost 0 for approximation value: 0.7853982350636618, and 11300 quadrature points with error: 0.000000072
# Error is almost 0 for approximation value: 0.7853982341229255, and 11400 quadrature points with error: 0.000000071
# Error is almost 0 for approximation value: 0.7853982332025954, and 11500 quadrature points with error: 0.000000070
# Error is almost 0 for approximation value: 0.7853982323020458, and 11600 quadrature points with error: 0.000000069
# Error is almost 0 for approximation value: 0.7853982314206974, and 11700 quadrature points with error: 0.000000068
# Error is almost 0 for approximation value: 0.7853982305579763, and 11800 quadrature points with error: 0.000000067
# Error is almost 0 for approximation value: 0.7853982297133422, and 11900 quadrature points with error: 0.000000066
# Error is almost 0 for approximation value: 0.7853982288862699, and 12000 quadrature points with error: 0.000000065
# Error is almost 0 for approximation value: 0.7853982280762346, and 12100 quadrature points with error: 0.000000065
# Error is almost 0 for approximation value: 0.7853982272827762, and 12200 quadrature points with error: 0.000000064
# Error is almost 0 for approximation value: 0.7853982265053961, and 12300 quadrature points with error: 0.000000063
# Error is almost 0 for approximation value: 0.7853982257436581, and 12400 quadrature points with error: 0.000000062
# Error is almost 0 for approximation value: 0.7853982249971273, and 12500 quadrature points with error: 0.000000062
# Error is almost 0 for approximation value: 0.7853982242653736, and 12600 quadrature points with error: 0.000000061
# Error is almost 0 for approximation value: 0.7853982235479892, and 12700 quadrature points with error: 0.000000060
# Error is almost 0 for approximation value: 0.7853982228445924, and 12800 quadrature points with error: 0.000000059
# Error is almost 0 for approximation value: 0.7853982221548014, and 12900 quadrature points with error: 0.000000059
# Error is almost 0 for approximation value: 0.7853982214782399, and 13000 quadrature points with error: 0.000000058
# Error is almost 0 for approximation value: 0.7853982208145672, and 13100 quadrature points with error: 0.000000057
# Error is almost 0 for approximation value: 0.7853982201634353, and 13200 quadrature points with error: 0.000000057
# Error is almost 0 for approximation value: 0.785398219524521, and 13300 quadrature points with error: 0.000000056
# Error is almost 0 for approximation value: 0.7853982188975024, and 13400 quadrature points with error: 0.000000056
# Error is almost 0 for approximation value: 0.7853982182820721, and 13500 quadrature points with error: 0.000000055
# Error is almost 0 for approximation value: 0.785398217677936, and 13600 quadrature points with error: 0.000000054
# Error is almost 0 for approximation value: 0.785398217084793, and 13700 quadrature points with error: 0.000000054
# Error is almost 0 for approximation value: 0.7853982165023801, and 13800 quadrature points with error: 0.000000053
# Error is almost 0 for approximation value: 0.7853982159304226, and 13900 quadrature points with error: 0.000000053
# Error is almost 0 for approximation value: 0.7853982153686548, and 14000 quadrature points with error: 0.000000052
# Error is almost 0 for approximation value: 0.7853982148168368, and 14100 quadrature points with error: 0.000000051
# Error is almost 0 for approximation value: 0.7853982142747088, and 14200 quadrature points with error: 0.000000051
# Error is almost 0 for approximation value: 0.785398213742036, and 14300 quadrature points with error: 0.000000050
# Error is almost 0 for approximation value: 0.7853982132186036, and 14400 quadrature points with error: 0.000000050
# Error is almost 0 for approximation value: 0.7853982127041742, and 14500 quadrature points with error: 0.000000049
# Error is almost 0 for approximation value: 0.7853982121985407, and 14600 quadrature points with error: 0.000000049
# Error is almost 0 for approximation value: 0.7853982117014806, and 14700 quadrature points with error: 0.000000048
# Error is almost 0 for approximation value: 0.7853982112128123, and 14800 quadrature points with error: 0.000000048
# Error is almost 0 for approximation value: 0.7853982107323225, and 14900 quadrature points with error: 0.000000047
# Error is almost 0 for approximation value: 0.7853982102598306, and 15000 quadrature points with error: 0.000000047
# Error is almost 0 for approximation value: 0.7853982097951441, and 15100 quadrature points with error: 0.000000046
# Error is almost 0 for approximation value: 0.7853982093380873, and 15200 quadrature points with error: 0.000000046
# Error is almost 0 for approximation value: 0.7853982088884887, and 15300 quadrature points with error: 0.000000045
# Error is almost 0 for approximation value: 0.7853982084461695, and 15400 quadrature points with error: 0.000000045
# Error is almost 0 for approximation value: 0.7853982080109676, and 15500 quadrature points with error: 0.000000045
# Error is almost 0 for approximation value: 0.7853982075827401, and 15600 quadrature points with error: 0.000000044
# Error is almost 0 for approximation value: 0.7853982071613161, and 15700 quadrature points with error: 0.000000044
# Error is almost 0 for approximation value: 0.7853982067465521, and 15800 quadrature points with error: 0.000000043
# Error is almost 0 for approximation value: 0.7853982063382872, and 15900 quadrature points with error: 0.000000043
# Error is almost 0 for approximation value: 0.7853982059364026, and 16000 quadrature points with error: 0.000000043
# Error is almost 0 for approximation value: 0.7853982055407379, and 16100 quadrature points with error: 0.000000042
# Error is almost 0 for approximation value: 0.7853982051511761, and 16200 quadrature points with error: 0.000000042
# Error is almost 0 for approximation value: 0.7853982047675812, and 16300 quadrature points with error: 0.000000041
# Error is almost 0 for approximation value: 0.7853982043898182, and 16400 quadrature points with error: 0.000000041
# Error is almost 0 for approximation value: 0.7853982040177702, and 16500 quadrature points with error: 0.000000041
# Error is almost 0 for approximation value: 0.7853982036513235, and 16600 quadrature points with error: 0.000000040
# Error is almost 0 for approximation value: 0.7853982032903417, and 16700 quadrature points with error: 0.000000040
# Error is almost 0 for approximation value: 0.785398202934729, and 16800 quadrature points with error: 0.000000040
# Error is almost 0 for approximation value: 0.7853982025843718, and 16900 quadrature points with error: 0.000000039
# Error is almost 0 for approximation value: 0.7853982022391475, and 17000 quadrature points with error: 0.000000039
# Error is almost 0 for approximation value: 0.7853982018989801, and 17100 quadrature points with error: 0.000000039
# Error is almost 0 for approximation value: 0.7853982015637274, and 17200 quadrature points with error: 0.000000038
# Error is almost 0 for approximation value: 0.7853982012333308, and 17300 quadrature points with error: 0.000000038
# Error is almost 0 for approximation value: 0.7853982009076605, and 17400 quadrature points with error: 0.000000038
# Error is almost 0 for approximation value: 0.7853982005866459, and 17500 quadrature points with error: 0.000000037
# Error is almost 0 for approximation value: 0.7853982002701823, and 17600 quadrature points with error: 0.000000037
# Error is almost 0 for approximation value: 0.7853981999581717, and 17700 quadrature points with error: 0.000000037
# Error is almost 0 for approximation value: 0.7853981996505504, and 17800 quadrature points with error: 0.000000036
# Error is almost 0 for approximation value: 0.7853981993472121, and 17900 quadrature points with error: 0.000000036
# Error is almost 0 for approximation value: 0.7853981990480846, and 18000 quadrature points with error: 0.000000036
# Error is almost 0 for approximation value: 0.7853981987530766, and 18100 quadrature points with error: 0.000000035
# Error is almost 0 for approximation value: 0.7853981984621162, and 18200 quadrature points with error: 0.000000035
# Error is almost 0 for approximation value: 0.7853981981751299, and 18300 quadrature points with error: 0.000000035
# Error is almost 0 for approximation value: 0.7853981978920365, and 18400 quadrature points with error: 0.000000034
# Error is almost 0 for approximation value: 0.7853981976127558, and 18500 quadrature points with error: 0.000000034
# Error is almost 0 for approximation value: 0.7853981973372257, and 18600 quadrature points with error: 0.000000034
# Error is almost 0 for approximation value: 0.7853981970653722, and 18700 quadrature points with error: 0.000000034
# Error is almost 0 for approximation value: 0.7853981967971342, and 18800 quadrature points with error: 0.000000033
# Error is almost 0 for approximation value: 0.785398196532446, and 18900 quadrature points with error: 0.000000033
# Error is almost 0 for approximation value: 0.7853981962712073, and 19000 quadrature points with error: 0.000000033
# Error is almost 0 for approximation value: 0.7853981960134191, and 19100 quadrature points with error: 0.000000033
# Error is almost 0 for approximation value: 0.7853981957589604, and 19200 quadrature points with error: 0.000000032
# Error is almost 0 for approximation value: 0.785398195507806, and 19300 quadrature points with error: 0.000000032
# Error is almost 0 for approximation value: 0.7853981952598693, and 19400 quadrature points with error: 0.000000032
# Error is almost 0 for approximation value: 0.785398195015111, and 19500 quadrature points with error: 0.000000032
# Error is almost 0 for approximation value: 0.7853981947734812, and 19600 quadrature points with error: 0.000000031
# Error is almost 0 for approximation value: 0.7853981945349008, and 19700 quadrature points with error: 0.000000031
# Error is almost 0 for approximation value: 0.7853981942993338, and 19800 quadrature points with error: 0.000000031
# Error is almost 0 for approximation value: 0.7853981940667142, and 19900 quadrature points with error: 0.000000031
# Error is almost 0 for approximation value: 0.7853981938370097, and 20000 quadrature points with error: 0.000000030
# Error is almost 0 for approximation value: 0.7853981936101605, and 20100 quadrature points with error: 0.000000030
# Error is almost 0 for approximation value: 0.7853981933861038, and 20200 quadrature points with error: 0.000000030
# Error is almost 0 for approximation value: 0.785398193164815, and 20300 quadrature points with error: 0.000000030
# Error is almost 0 for approximation value: 0.7853981929462168, and 20400 quadrature points with error: 0.000000030
# Error is almost 0 for approximation value: 0.7853981927302974, and 20500 quadrature points with error: 0.000000029
# Error is almost 0 for approximation value: 0.78539819251699, and 20600 quadrature points with error: 0.000000029
# Error is almost 0 for approximation value: 0.7853981923062482, and 20700 quadrature points with error: 0.000000029
# Error is almost 0 for approximation value: 0.7853981920980412, and 20800 quadrature points with error: 0.000000029
# Error is almost 0 for approximation value: 0.7853981918923284, and 20900 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981916890547, and 21000 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981914881837, and 21100 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981912896889, and 21200 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981910935222, and 21300 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981908996273, and 21400 quadrature points with error: 0.000000028
# Error is almost 0 for approximation value: 0.7853981907079923, and 21500 quadrature points with error: 0.000000027
# Error is almost 0 for approximation value: 0.7853981905185755, and 21600 quadrature points with error: 0.000000027
# Error is almost 0 for approximation value: 0.7853981903313373, and 21700 quadrature points with error: 0.000000027
# Error is almost 0 for approximation value: 0.7853981901462432, and 21800 quadrature points with error: 0.000000027
# Error is almost 0 for approximation value: 0.785398189963254, and 21900 quadrature points with error: 0.000000027
# Error is almost 0 for approximation value: 0.7853981897823503, and 22000 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.7853981896034808, and 22100 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.7853981894266354, and 22200 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.78539818925176, and 22300 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.7853981890788385, and 22400 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.7853981889078404, and 22500 quadrature points with error: 0.000000026
# Error is almost 0 for approximation value: 0.7853981887387309, and 22600 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.78539818857147, and 22700 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.7853981884060534, and 22800 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.7853981882424261, and 22900 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.785398188080582, and 23000 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.7853981879204935, and 23100 quadrature points with error: 0.000000025
# Error is almost 0 for approximation value: 0.785398187762131, and 23200 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.7853981876054539, and 23300 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.785398187450456, and 23400 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.7853981872970972, and 23500 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.785398187145375, and 23600 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.7853981869952364, and 23700 quadrature points with error: 0.000000024
# Error is almost 0 for approximation value: 0.7853981868466814, and 23800 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981866996781, and 23900 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981865541959, and 24000 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981864102317, and 24100 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.785398186267754, and 24200 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981861267354, and 24300 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981859871599, and 24400 quadrature points with error: 0.000000023
# Error is almost 0 for approximation value: 0.7853981858490043, and 24500 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981857122572, and 24600 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981855768905, and 24700 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981854428871, and 24800 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981853102265, and 24900 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.785398185178903, and 25000 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981850488706, and 25100 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981849201306, and 25200 quadrature points with error: 0.000000022
# Error is almost 0 for approximation value: 0.7853981847926595, and 25300 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981846664437, and 25400 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981845414671, and 25500 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981844177046, and 25600 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981842951523, and 25700 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981841737834, and 25800 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981840535762, and 25900 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.785398183934536, and 26000 quadrature points with error: 0.000000021
# Error is almost 0 for approximation value: 0.7853981838166232, and 26100 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981836998397, and 26200 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981835841629, and 26300 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981834695923, and 26400 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981833560842, and 26500 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981832436533, and 26600 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981831322688, and 26700 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981830219248, and 26800 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981829126074, and 26900 quadrature points with error: 0.000000020
# Error is almost 0 for approximation value: 0.7853981828042987, and 27000 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981826969861, and 27100 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981825906579, and 27200 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981824853082, and 27300 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981823809207, and 27400 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981822774763, and 27500 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981821749679, and 27600 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981820733811, and 27700 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981819727174, and 27800 quadrature points with error: 0.000000019
# Error is almost 0 for approximation value: 0.7853981818729425, and 27900 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981817740552, and 28000 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981816760649, and 28100 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981815789246, and 28200 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981814826555, and 28300 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981813872193, and 28400 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981812926203, and 28500 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981811988622, and 28600 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981811059039, and 28700 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981810137595, and 28800 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981809224165, and 28900 quadrature points with error: 0.000000018
# Error is almost 0 for approximation value: 0.7853981808318522, and 29000 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981807420664, and 29100 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981806530506, and 29200 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981805647949, and 29300 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981804772785, and 29400 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981803905251, and 29500 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981803044832, and 29600 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981802191716, and 29700 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981801345783, and 29800 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981800506814, and 29900 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981799674936, and 30000 quadrature points with error: 0.000000017
# Error is almost 0 for approximation value: 0.7853981798849953, and 30100 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981798031793, and 30200 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981797220317, and 30300 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981796415568, and 30400 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981795617367, and 30500 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981794825681, and 30600 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981794040493, and 30700 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981793261651, and 30800 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981792488982, and 30900 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981791722677, and 31000 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981790962458, and 31100 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.7853981790208454, and 31200 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.785398178946028, and 31300 quadrature points with error: 0.000000016
# Error is almost 0 for approximation value: 0.785398178871818, and 31400 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981787981972, and 31500 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981787251623, and 31600 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981786526946, and 31700 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.785398178580794, and 31800 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981785094649, and 31900 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981784386871, and 32000 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981783684629, and 32100 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.785398178298768, and 32200 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981782296384, and 32300 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981781610215, and 32400 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981780929447, and 32500 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981780253785, and 32600 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981779583249, and 32700 quadrature points with error: 0.000000015
# Error is almost 0 for approximation value: 0.7853981778917972, and 32800 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981778257658, and 32900 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981777602366, and 33000 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981776951966, and 33100 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981776306546, and 33200 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981775665938, and 33300 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981775030087, and 33400 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981774398978, and 33500 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981773772675, and 33600 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981773150938, and 33700 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.785398177253375, and 33800 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981771921151, and 33900 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981771313049, and 34000 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981770709308, and 34100 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981770110086, and 34200 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.785398176951525, and 34300 quadrature points with error: 0.000000014
# Error is almost 0 for approximation value: 0.7853981768924762, and 34400 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981768338419, and 34500 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981767756347, and 34600 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981767178525, and 34700 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981766604768, and 34800 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981766035244, and 34900 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981765469713, and 35000 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.785398176490814, and 35100 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981764350578, and 35200 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981763797058, and 35300 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.785398176324737, and 35400 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981762701532, and 35500 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981762159639, and 35600 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981761621428, and 35700 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981761086984, and 35800 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981760556316, and 35900 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981760029248, and 36000 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981759505803, and 36100 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.785398175898616, and 36200 quadrature points with error: 0.000000013
# Error is almost 0 for approximation value: 0.7853981758469899, and 36300 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.785398175795722, and 36400 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.785398175744814, and 36500 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981756942469, and 36600 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.785398175644013, and 36700 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981755941412, and 36800 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.785398175544598, and 36900 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981754953908, and 37000 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981754465116, and 37100 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981753979568, and 37200 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981753497359, and 37300 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981753018361, and 37400 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981752542591, and 37500 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981752069908, and 37600 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981751600282, and 37700 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981751133866, and 37800 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981750670431, and 37900 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981750210173, and 38000 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981749752963, and 38100 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.7853981749298626, and 38200 quadrature points with error: 0.000000012
# Error is almost 0 for approximation value: 0.785398174884724, and 38300 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981748398886, and 38400 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981747953438, and 38500 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981747510744, and 38600 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981747070959, and 38700 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981746634043, and 38800 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981746199915, and 38900 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981745768609, and 39000 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981745340044, and 39100 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.785398174491423, and 39200 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981744490947, and 39300 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981744070565, and 39400 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981743652725, and 39500 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981743237607, and 39600 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.785398174282495, and 39700 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981742415149, and 39800 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981742007652, and 39900 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981741602907, and 40000 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981741200496, and 40100 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981740800662, and 40200 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981740403374, and 40300 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981740008411, and 40400 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981739616034, and 40500 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981739225846, and 40600 quadrature points with error: 0.000000011
# Error is almost 0 for approximation value: 0.7853981738838295, and 40700 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981738453104, and 40800 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981738070028, and 40900 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981737689468, and 41000 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981737311255, and 41100 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981736935277, and 41200 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981736561656, and 41300 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981736190151, and 41400 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981735820822, and 41500 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981735453955, and 41600 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981735089103, and 41700 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981734726403, and 41800 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981734366081, and 41900 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981734007746, and 42000 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981733651536, and 42100 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981733297498, and 42200 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981732945556, and 42300 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.785398173259562, and 42400 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981732247718, and 42500 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981731901828, and 42600 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981731558107, and 42700 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981731216365, and 42800 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981730876572, and 42900 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981730538747, and 43000 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981730202977, and 43100 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.785398172986904, and 43200 quadrature points with error: 0.000000010
# Error is almost 0 for approximation value: 0.7853981729537023, and 43300 quadrature points with error: 0.000000010
# ...
# Error is almost 0 for approximation value: 0.7853981667997559, and 86200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667938448, and 86300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667879495, and 86400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667820865, and 86500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166776214, and 86600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667703652, and 86700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667645388, and 86800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166758713, and 86900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667529459, and 87000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667471623, and 87100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667413942, and 87200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667356572, and 87300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667299325, and 87400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667242173, and 87500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667185295, and 87600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667128462, and 87700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667071911, and 87800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981667015352, and 87900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666958983, and 88000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666902916, and 88100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666846944, and 88200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166679106, and 88300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666735381, and 88400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666679944, and 88500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666624498, and 88600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666569291, and 88700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666514448, and 88800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666459402, and 88900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666404698, and 89000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666350167, and 89100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666295824, and 89200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666241379, and 89300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166618729, and 89400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666133275, and 89500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166607951, and 89600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981666025789, and 89700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665972305, and 89800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665918915, and 89900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665865774, and 90000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665812636, and 90100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665759825, and 90200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665706997, and 90300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665654262, and 90400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665601933, and 90500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665549464, and 90600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665497218, and 90700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665445163, and 90800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166539332, and 90900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665341443, and 91000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665290022, and 91100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665238416, and 91200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665187033, and 91300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166513593, and 91400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166508472, and 91500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981665033912, and 91600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664982959, and 91700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664932338, and 91800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664881863, and 91900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664831519, and 92000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664781275, and 92100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166473123, and 92200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166468132, and 92300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664631426, and 92400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664581595, and 92500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664532136, and 92600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664482617, and 92700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664433257, and 92800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664384173, and 92900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166433516, and 93000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664286175, and 93100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664237657, and 93200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166418888, and 93300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.78539816641403, and 93400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664091834, and 93500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981664043681, and 93600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663995637, and 93700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663947446, and 93800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663899683, and 93900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663852041, and 94000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663804428, and 94100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663756736, and 94200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663709504, and 94300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663662368, and 94400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663615085, and 94500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663568149, and 94600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663521364, and 94700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166347468, and 94800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663428024, and 94900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663381538, and 95000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663334965, and 95100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663288759, and 95200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166324272, and 95300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663196707, and 95400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663150832, and 95500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663105017, and 95600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663059384, and 95700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981663013915, and 95800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662968498, and 95900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662923113, and 96000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662878058, and 96100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662832896, and 96200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662787938, and 96300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662743234, and 96400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662698502, and 96500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662653916, and 96600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662609505, and 96700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662565124, and 96800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662520844, and 96900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662476724, and 97000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662432732, and 97100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662388817, and 97200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662344913, and 97300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662301343, and 97400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662257725, and 97500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662214287, and 97600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662170849, and 97700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662127651, and 97800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662084668, and 97900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981662041659, and 98000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661998666, and 98100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661955874, and 98200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661913123, and 98300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661870539, and 98400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661828051, and 98500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661785682, and 98600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166174339, and 98700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661701408, and 98800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661659317, and 98900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661617452, and 99000 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166157557, and 99100 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661533733, and 99200 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661492251, and 99300 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.785398166145066, and 99400 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661409255, and 99500 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661367979, and 99600 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661326779, and 99700 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661285707, and 99800 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661244814, and 99900 quadrature points with error: 0.000000003
# Error is almost 0 for approximation value: 0.7853981661203832, and 100000 quadrature points with error: 0.000000003

# %% [markdown]
# #### Observations

# %% [markdown]
# - Convergence for midpoint rule is achieved faster as compared to monte carlo, we can achieve almost 0 error with approx 100 quadrature points.

# %% [markdown]
# <img src = './2.jpg'>
